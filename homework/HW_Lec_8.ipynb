# %% [markdown]
# ## 8.5 Homework
# Write your own program to do the followings
# - generate a data with random noise
# - choose different polynomial function to fit the data
# - discuss which polynomial function yields the best fit and give your reasoning.

# %%
# %matplotlib inline  

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=[12, 8])
#define the function
f = lambda x: np.log(x)  

#define the paramters for the plot
a,b = 1,11
npoints = 100

x = np.linspace(a,b,npoints)
y = f(x) + np.random.rand(npoints) - 0.5

plt.plot(x,f(x), label='ideal function')
plt.plot(x,y, 'o', label='noisy data')
plt.plot(x,y_p, label='polyfit'+str(order))

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.xlim([a,b])
plt.legend(fontsize=12)
plt.title('Ln(x)')
plt.show()
#plt.text(2, 2, fit)

# %%
# plt.figure(figsize=[12, 8])

order = 0

# plt.plot(x,y, 'o', label='noisy data')

for order in range(21):
    fit = np.polyfit(x, y, order, full=True)
    y_p = np.polyval(fit[0], x)
    
    plt.plot(x,f(x), label='ideal function')
    plt.plot(x,y_p, label='polyfit'+str(order))

    plt.xlabel('x')
    plt.ylabel('$f(x)$')
    plt.xlim([a,b])
    plt.legend(fontsize=12)
    plt.title('Ln(x)')
    plt.show()

# %% [markdown]
# 4th order appears to be the best so lets run it for longer and see if it holds up as the function progresses

# %%
plt.figure(figsize=[12, 8])

order = 4


a = 1
b = 100
npoints = 1000


x = np.linspace(a,b,npoints)
y = f(x) + np.random.rand(npoints) - 0.5

fit = np.polyfit(x, y, order, full=True)
y_p = np.polyval(fit[0], x)

plt.plot(x,f(x), label='ideal function')
plt.plot(x,y_p, label='polyfit'+str(order))
# plt.plot(x,y, 'o', label='noisy data')

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.xlim([a,b])
plt.legend(fontsize=12)
plt.title('Ln(x)')
plt.show()

# %%
plt.figure(figsize=[12, 8])

order = 8


a = 1
b = 100
npoints = 1000


x = np.linspace(a,b,npoints)
y = f(x) + np.random.rand(npoints) - 0.5

fit = np.polyfit(x, y, order, full=True)
y_p = np.polyval(fit[0], x)

plt.plot(x,f(x), label='ideal function')
plt.plot(x,y_p, label='polyfit'+str(order))
# plt.plot(x,y, 'o', label='noisy data')

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.xlim([a,b])
plt.legend(fontsize=12)
plt.title('Ln(x)')
plt.show()

# %% [markdown]
# With a very large set of data, 8th order fit actually seems to do better
